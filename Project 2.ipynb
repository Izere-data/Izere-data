# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %% [markdown]
# ## Let's import our datasets

# %%
data=pd.read_csv("C:/Users/user/Desktop/datasets/healthcare-dataset-stroke-data.csv") 
print(df)
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %% [markdown]
# ### Data cleaning

# %% [markdown]
# #### checking for missing values

# %%
print(data.isnull().sum())
# Out:
# id                     0
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# ever_married           0
# work_type              0
# Residence_type         0
# avg_glucose_level      0
# bmi                  201
# smoking_status         0
# stroke                 0
# dtype: int64

# %% [markdown]
# ##### the output is indicating that there are no missing values in most columns ao the dataset except for the 'bmi' column which has 201 missing entries

# %%
data['stroke'] = data['stroke'].astype(int)
print(data['stroke'])
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 5105    0
# 5106    0
# 5107    0
# 5108    0
# 5109    0
# Name: stroke, Length: 5110, dtype: int32

# %% [markdown]
# ##### 0, 1: These values represent the binary classification of the stroke variable, where:
#
# ##### 1 indicates that a stroke occurred.
# ##### 0 indicates that no stroke occurred.

# %% [markdown]
# ### Let's do Data analysis

# %%
import numpy as np

# %%
print(data.loc[0:5109,['age']])
# Out:
#        age
# 0     67.0
# 1     61.0
# 2     80.0
# 3     49.0
# 4     79.0
# ...    ...
# 5105  80.0
# 5106  81.0
# 5107  35.0
# 5108  51.0
# 5109  44.0
#
# [5110 rows x 1 columns]

# %%
average_age = np.mean(data['age'])
print(average_age)

# %%
sorted_ages = data['age'].sort_values()
print(sorted_ages)
# Out:
# 3295     0.08
# 1614     0.08
# 3618     0.16
# 4021     0.16
# 3968     0.16
#         ...
# 4590    82.00
# 4094    82.00
# 2341    82.00
# 4716    82.00
# 187     82.00
# Name: age, Length: 5110, dtype: float64

# %% [markdown]
# ##### Here we have the ages by ascending order

# %% [markdown]
# ### Let's visualize Data

# %%
plt.figure(figsize=(12,6))

# %%
plt.xlabel('age')
plt.ylabel('stroke')
plt.grid()
plt.show()

# %%
import seaborn as sns

# %% [markdown]
# ### Plot1: age distribution

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['age'], kde=True, bins=30, color='skyblue')
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ##### This plot is  showing the distribution of ages in the dataset, helping you understand the general age range.

# %% [markdown]
# ### Plot2: Stroke occurences by age

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='age', y='stroke', data=df, hue='stroke', palette='coolwarm')
plt.title('Stroke Occurrences by Age')
plt.xlabel('Age')
plt.ylabel('Stroke (1 = Stroke, 0 = No Stroke)')
plt.show()

# %% [markdown]
# ##### A scatter plot which visualize how age relates to stroke occurrences

# %% [markdown]
# ### Plot3: Correlation heatmap

# %% [markdown]
# ##### Let's select only numeeical columss first off

# %%
numeric_df = df.select_dtypes(include=['float64', 'int64'])

# %% [markdown]
# ##### Then correlation matrix

# %%
plt.figure(figsize=(10, 8))
corr = numeric_df.corr()

# %% [markdown]
# ##### Heatmap

# %%
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap')
plt.show()
